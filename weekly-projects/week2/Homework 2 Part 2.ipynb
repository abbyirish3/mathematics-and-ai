# %%
# Homework 2 Part 2 (due 7/07/2024)

# %% [markdown]
# # Health-care assistance via probabilistic graphical modeling
#
# ### Objective
# In this project, you will create a health-care assistance bot that can suggest diagnoses for a set of symptoms based on a probabilistic graphical model.
#
# ### Step 1: Review
# Review the code from the Bayesian networks exercise.
#
# ### Step 2: Acquire data
# View this [research article](https://www.nature.com/articles/ncomms5212) and download its supplementary data sets 1, 2 and 3. These data sets include the occurrences of diseases, symptoms, and their co-occurrences in the scientific literature. (For the purpose of this exercise, we are going to assume that the frequency of co-occurrences of diseases and symptoms in scientific papers is proportional to the co-occurence frequencies of actual disease cases and symptoms.)
#
# ### Step 3: Create a Bayesian network
# Using commands from the `pgmpy` library, create a Bayesian network in which the probability of exhibiting a symptom is conditional on the probability of having an associated disease.
#
# ### Step 4: Initialize priors
# Use the disease occurrence data to assign prior probabilities for diseases.
#
# ### Step 5: Calculate conditional probability tables
# Use the co-occurrence data to define CPTs for each connected pair of disease and symptoms. (Hint: You may need to assign some occurrences of symptoms to an "idiopathic disease" to create valid CPTs.)
#
# ### Step 6:
# Create a minimal interface in which your bot asks a users for a list of observed symptoms and then returns the name of the disease that is the most likely match to the symptoms. (Hint: Review the input/output commands that you have used in last week's homework.)

# %%
import pgmpy as pg
import pandas as pd
import numpy as np
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# %%
# Step 3: Create Bayesian Network
diseases = pd.read_csv("supp_data_1.txt", sep = "\t")
symptoms = pd.read_csv("supp_data_2.txt", sep = "\t") 
cooccurrences = pd.read_csv("supp_data_3.txt", sep = "\t")

diseases = diseases.to_numpy()
symptoms = symptoms.to_numpy()
cooccurrences = cooccurrences.to_numpy()

disease_name = diseases.T[0]
disease_occ = diseases.T[1]
symptom_name = symptoms.T[0]
symptom_occ = symptoms.T[1]

model = BayesianNetwork()

print(symptom_occ)

network_diseases = []
for i in range(len(disease_occ)):
    if i > 500:
        model.add_node("Disease: " + disease_name[i])
        network_diseases.append(disease_name[i])

for i in range(len(symptom_occ)): 
    model.add_node("Symptom :" + symptom_name[i])
    for d in range(len(network_diseases)):
        model.add_edge(d, symptom_name[i])

model.add_node("idiopathic disease")

print(network_diseases)
print(model)
# Out:
# [147857 103168 100301 47351 43883 36959 34850 29473 29446 29364 27734
#  22793 21470 20212 19403 18689 18661 18604 17571 16827 16162 15975 15477
#  15199 13385 12973 12913 12844 12076 11643 11489 11450 11361 11096 10577
#  10544 10308 10187 10094 9677 9513 9207 9201 8659 8445 8320 8193 8094 7916
#  7774 7771 7764 7754 7742 7698 7693 7494 7345 7236 7078 6702 6660 6658
#  6617 6461 6418 6300 6081 5975 5973 5941 5870 5835 5800 5749 5710 5639
#  5549 5523 5455 5395 5240 5135 5119 5096 5038 4918 4711 4648 4576 4573
#  4516 4496 4424 4410 4304 4301 4252 4190 4124 4102 4043 3958 3869 3857
#  3800 3752 3748 3616 3469 3387 3375 3369 3368 3364 3297 3286 3274 3274
#  3268 3264 3242 3235 3213 3169 3150 2970 2841 2815 2806 2784 2780 2771
#  2747 2723 2639 2616 2574 2556 2476 2338 2331 2232 2228 2206 2200 2148
#  2137 2136 2119 2089 2077 2065 2052 2022 1953 1840 1816 1792 1788 1784
#  1779 1763 1753 1745 1739 1679 1661 1649 1591 1586 1539 1511 1502 1490
#  1485 1458 1448 1440 1409 1370 1331 1329 1302 1298 1291 1278 1264 1241
#  1209 1174 1163 1122 1100 1091 1075 1071 1045 1002 999 970 953 949 937 935
#  914 906 894 884 859 833 833 828 822 786 783 782 782 773 768 751 691 688
#  686 661 595 587 576 557 545 539 519 518 506 498 485 472 435 428 417 404
#  385 378 376 360 348 346 340 321 320 315 310 307 286 278 272 270 264 257
#  252 251 249 242 242 240 239 237 236 236 224 224 223 222 217 214 209 208
#  202 194 188 181 174 173 169 149 139 136 134 129 126 124 115 113 106 93 87
#  81 78 76 73 66 65 63 55 52 50 50 45 42 32 28 24 22 20 19 18 11 10 7 4 3 2]
# ['Neurodegenerative Diseases', 'Nerve Compression Syndromes', 'Salmonella Infections', 'Mood Disorders', 'Pneumonia, Bacterial', 'Renal Artery Obstruction', 'Cough', 'Gout', 'Herpes Zoster', 'Spinal Neoplasms', 'Lung Diseases, Fungal', 'Neoplasms, Second Primary', 'Urination Disorders', 'Facial Paralysis', 'Choristoma', 'Gonadal Dysgenesis', 'Strabismus', 'Myocardial Reperfusion Injury', 'Lyme Disease', 'Hemochromatosis', 'Puerperal Disorders', 'Corneal Diseases', 'Coma', 'Angina, Unstable', 'Syncope', 'Rodent Diseases', 'Heart Septal Defects, Atrial', 'Toxoplasmosis', 'Dizziness', 'Paraplegia', 'Papilloma', 'Dyspnea', 'Typhoid Fever', 'Alcoholic Intoxication', 'Ophthalmoplegia', 'Duodenal Diseases', 'Aortic Aneurysm, Abdominal', 'Antiphospholipid Syndrome', 'Agranulocytosis', 'Esophageal Diseases', 'Pemphigus', 'Wilms Tumor', 'Liver Cirrhosis, Biliary', 'beta-Thalassemia', 'Chagas Disease', 'Cicatrix', 'Dermatitis, Occupational', 'Pigmentation Disorders', 'Urinary Bladder Diseases', 'Urologic Diseases', 'Lymphoproliferative Disorders', 'Nerve Degeneration', 'Sleep Initiation and Maintenance Disorders', 'Chronic Disease', 'Epilepsies, Partial', 'Foot Diseases', 'Thymus Neoplasms', 'Renal Insufficiency', 'Retroperitoneal Neoplasms', 'Acromegaly', 'Aphasia', 'Intracranial Embolism and Thrombosis', 'Joint Instability', 'Pregnancy, Ectopic', 'Autonomic Nervous System Diseases', 'Carcinoma, Bronchogenic', 'Eye Injuries', 'Retinal Degeneration', 'Nose Neoplasms', 'Rheumatic Heart Disease', 'Wounds, Gunshot', 'Myopia', 'Osteoarthritis, Knee', 'Rhinitis, Allergic, Perennial', 'Porphyrias', 'Poisoning', 'Bird Diseases', 'Anemia, Hypochromic', 'Spinal Cord Neoplasms', 'Intestinal Fistula', 'Myositis', 'Dystonia', 'Rhabdomyosarcoma', 'Bronchial Diseases', 'Arthritis, Experimental', 'Neoplasms, Germ Cell and Embryonal', 'Salivary Gland Neoplasms', 'Aortic Valve Insufficiency', 'Cerebellar Neoplasms', 'Spinal Cord Compression', 'Brucellosis', 'Abortion, Spontaneous', 'Coronary Stenosis', 'Substance Abuse, Intravenous', 'Wounds, Penetrating', 'Speech Disorders', 'Coronary Vessel Anomalies', 'Infectious Mononucleosis', 'Plasmacytoma', 'Pneumonia, Pneumocystis', 'Vaccinia', 'Melanoma, Experimental', 'Pneumococcal Infections', 'Rheumatic Fever', 'Amenorrhea', 'Obstetric Labor, Premature', 'Leiomyosarcoma', 'Embolism', 'Somatoform Disorders', 'Hamartoma', 'Hematologic Neoplasms', 'Abnormalities, Drug-Induced', 'Cleft Lip', 'Aneurysm, False', 'Turner Syndrome', 'Rhinitis', 'Dermatomycoses', 'Bundle-Branch Block', 'Hemiplegia', 'Wegener Granulomatosis', 'Orbital Neoplasms', 'Arteriovenous Malformations', 'Hyponatremia', 'Leukemia, Promyelocytic, Acute', 'Fibromyalgia', 'Abdominal Neoplasms', 'Dyslexia', 'Muscular Atrophy', 'Mandibular Neoplasms', 'Pregnancy Complications, Hematologic', 'Hearing Loss', 'Cervical Intraepithelial Neoplasia', 'Neuralgia', 'Multiple Trauma', 'Nevus, Pigmented', 'Leishmaniasis, Visceral', 'Communicable Diseases', 'Parotid Neoplasms', 'Hypertension, Renovascular', 'Pericarditis', 'Protein-Energy Malnutrition', 'Gram-Negative Bacterial Infections', 'Hypogonadism', 'Optic Nerve Diseases', 'Phenylketonurias', 'Intracranial Arteriovenous Malformations', 'Brain Abscess', 'Albuminuria', 'Panic Disorder', 'Hypoxia, Brain', 'Sexually Transmitted Diseases', 'Tibial Fractures', 'Thyroiditis, Autoimmune', 'Retinitis Pigmentosa', 'Gram-Positive Bacterial Infections', 'Hyperlipoproteinemia Type II', 'Dyskinesia, Drug-Induced', 'Fetal Death', 'Amebiasis', 'Dermatomyositis', 'Malabsorption Syndromes', 'Carcinoma, Intraductal, Noninfiltrating', 'Spinal Fractures', 'Tongue Neoplasms', 'Polyps', 'Retinoblastoma', 'Giant Cell Arteritis', 'Infertility', 'Splenic Diseases', 'Graft Occlusion, Vascular', 'Status Epilepticus', 'Sexual Dysfunction, Physiological', 'Lung Diseases, Interstitial', 'Barrett Esophagus', 'Vulvar Neoplasms', 'Skin Diseases, Vesiculobullous', 'Hyperaldosteronism', 'Myxoma', 'Hematuria', 'Long QT Syndrome', 'Mycobacteri ...
# BayesianNetwork with 8527 nodes and 1269002 edges

# %%
# Step 4: initialize prior probabilities

total = sum(disease_occ)

prior_prob_list = []

for i in range(len(disease_name)): 
    if disease_name[i] in model:
        prior_prob = disease_occ[i] / total
        prior_prob_list.append(prior_prob)

        cpd = TabularCPD(variable = disease_name[i], 
                        variable_card = 2, 
                        values = [[1 - prior_prob], [prior_prob]])
        
        model.add_cpds(cpd)

print(len(disease_name))
print(prior_prob_list)
# assert model.check_model()
# Out:
# WARNING:pgmpy:Replacing existing CPD for Obesity
# WARNING:pgmpy:Replacing existing CPD for Pain
# WARNING:pgmpy:Replacing existing CPD for Seizures
# WARNING:pgmpy:Replacing existing CPD for Mental Retardation
# WARNING:pgmpy:Replacing existing CPD for Angina Pectoris
# WARNING:pgmpy:Replacing existing CPD for Pain, Postoperative
# WARNING:pgmpy:Replacing existing CPD for Deafness
# WARNING:pgmpy:Replacing existing CPD for Vision Disorders
# WARNING:pgmpy:Replacing existing CPD for Headache
# WARNING:pgmpy:Replacing existing CPD for Memory Disorders
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Sensorineural
# WARNING:pgmpy:Replacing existing CPD for Sleep Disorders
# WARNING:pgmpy:Replacing existing CPD for Urinary Incontinence
# WARNING:pgmpy:Replacing existing CPD for Low Back Pain
# WARNING:pgmpy:Replacing existing CPD for Paralysis
# WARNING:pgmpy:Replacing existing CPD for Back Pain
# WARNING:pgmpy:Replacing existing CPD for Learning Disorders
# WARNING:pgmpy:Replacing existing CPD for Hearing Disorders
# WARNING:pgmpy:Replacing existing CPD for Blindness
# WARNING:pgmpy:Replacing existing CPD for Proteinuria
# WARNING:pgmpy:Replacing existing CPD for Cough
# WARNING:pgmpy:Replacing existing CPD for Facial Paralysis
# WARNING:pgmpy:Replacing existing CPD for Coma
# WARNING:pgmpy:Replacing existing CPD for Angina, Unstable
# WARNING:pgmpy:Replacing existing CPD for Syncope
# WARNING:pgmpy:Replacing existing CPD for Dizziness
# WARNING:pgmpy:Replacing existing CPD for Paraplegia
# WARNING:pgmpy:Replacing existing CPD for Dyspnea
# WARNING:pgmpy:Replacing existing CPD for Ophthalmoplegia
# WARNING:pgmpy:Replacing existing CPD for Aphasia
# WARNING:pgmpy:Replacing existing CPD for Dystonia
# WARNING:pgmpy:Replacing existing CPD for Speech Disorders
# WARNING:pgmpy:Replacing existing CPD for Hemiplegia
# WARNING:pgmpy:Replacing existing CPD for Dyslexia
# WARNING:pgmpy:Replacing existing CPD for Muscular Atrophy
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss
# WARNING:pgmpy:Replacing existing CPD for Neuralgia
# WARNING:pgmpy:Replacing existing CPD for Albuminuria
# WARNING:pgmpy:Replacing existing CPD for Vertigo
# WARNING:pgmpy:Replacing existing CPD for Jaundice
# WARNING:pgmpy:Replacing existing CPD for Purpura, Thrombocytopenic
# WARNING:pgmpy:Replacing existing CPD for Tremor
# WARNING:pgmpy:Replacing existing CPD for Pain, Intractable
# WARNING:pgmpy:Replacing existing CPD for Pruritus
# WARNING:pgmpy:Replacing existing CPD for Hallucinations
# WARNING:pgmpy:Replacing existing CPD for Amnesia
# WARNING:pgmpy:Replacing existing CPD for Hyperalgesia
# WARNING:pgmpy:Replacing existing CPD for Amblyopia
# WARNING:pgmpy:Replacing existing CPD for Acute Coronary Syndrome
# WARNING:pgmpy:Replacing existing CPD for Obesity, Morbid
# WARNING:pgmpy:Replacing existing CPD for Language Disorders
# WARNING:pgmpy:Replacing existing CPD for Cardiac Output, Low
# WARNING:pgmpy:Replacing existing CPD for Muscle Weakness
# WARNING:pgmpy:Replacing existing CPD for Purpura, Thrombocytopenic, Idiopathic
# WARNING:pgmpy:Replacing existing CPD for Urinary Bladder, Neurogenic
# WARNING:pgmpy:Replacing existing CPD for Perceptual Disorders
# WARNING:pgmpy:Replacing existing CPD for Intermittent Claudication
# WARNING:pgmpy:Replacing existing CPD for Tinnitus
# WARNING:pgmpy:Replacing existing CPD for Myoclonus
# WARNING:pgmpy:Replacing existing CPD for Delirium
# WARNING:pgmpy:Replacing existing CPD for Urinary Incontinence, Stress
# WARNING:pgmpy:Replacing existing CPD for Apnea
# WARNING:pgmpy:Replacing existing CPD for Muscle Spasticity
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Noise-Induced
# WARNING:pgmpy:Replacing existing CPD for Purpura, Thrombotic Thrombocytopenic
# WARNING:pgmpy:Replacing existing CPD for Quadriplegia
# WARNING:pgmpy:Replacing existing CPD for Voice Disorders
# WARNING:pgmpy:Replacing existing CPD for Purpura, Schoenlein-Henoch
# WARNING:pgmpy:Replacing existing CPD for Language Development Disorders
# WARNING:pgmpy:Replacing existing CPD for Ataxia
# WARNING:pgmpy:Replacing existing CPD for Facial Pain
# WARNING:pgmpy:Replacing existing CPD for Hemoptysis
# WARNING:pgmpy:Replacing existing CPD for Spasm
# WARNING:pgmpy:Replacing existing CPD for Cerebellar Ataxia
# WARNING:pgmpy:Replacing existing CPD for Chorea
# WARNING:pgmpy:Replacing existing CPD for Vocal Cord Paralysis
# WARNING:pgmpy:Replacing existing CPD for Purpura
# WARNING:pgmpy:Replacing existing CPD for Stuttering
# WARNING:pgmpy:Replacing existing CPD for Sciatica
# WARNING:pgmpy:Replacing existing CPD for Color Vision Defects
# WARNING:pgmpy:Replacing existing CPD for Hyperventilation
# WARNING:pgmpy:Replacing existing CPD for Hypergammaglobulinemia
# WARNING:pgmpy:Replacing existing CPD for Psychomotor Disorders
# WARNING:pgmpy:Replacing existing CPD for Hyperkinesis
# WARNING:pgmpy:Replacing existing CPD for Hirsutism
# WARNING:pgmpy:Replacing existing CPD for Sleep Deprivation
# WARNING:pgmpy:Replacing existing CPD for Sensation Disorders
# WARNING:pgmpy:Replacing existing CPD for Neck Pain
# WARNING:pgmpy:Replacing existing CPD for Olfaction Disorders
# WARNING:pgmpy:Replacing existing CPD for Torticollis
# WARNING:pgmpy:Replacing existing CPD for Paresthesia
# WARNING:pgmpy:Replacing existing CPD for Arthralgia
# WARNING:pgmpy:Replacing existing CPD for Fetal Hypoxia
# WARNING:pgmpy:Replacing existing CPD for Paresis
# WARNING:pgmpy:Replacing existing CPD for Psychomotor Agitation
# WARNING:pgmpy:Replacing existing CPD for Dysmenorrhea
# WARNING:pgmpy:Replacing existing CPD for Gait Disorders, Neurologic
# WARNING:pgmpy:Replacing existing CPD for Apraxias
# WARNING:pgmpy:Replacing existing CPD for Angina Pectoris, Variant
# WARNING:pgmpy:Replacing existing CPD for Urinary Bladder, Overactive
# WARNING:pgmpy:Replacing existing CPD for Diplopia
# WARNING:pgmpy:Replacing existing CPD for Confusion
# WARNING:pgmpy:Replacing existing CPD for Supranuclear Palsy, Progressive
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Sudden
# WARNING:pgmpy:Replacing existing CPD for Hemianopsia
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Conductive
# WARNING:pgmpy:Replacing existing CPD for Shoulder Pain
# WARNING:pgmpy:Replacing existing CPD for Agnosia
# WARNING:pgmpy:Replacing existing CPD for Unconsciousness
# WARNING:pgmpy:Replacing existing CPD for Catatonia
# WARNING:pgmpy:Replacing existing CPD for Hydrops Fetalis
# WARNING:pgmpy:Replacing existing CPD for Cerebrospinal Fluid Rhinorrhea
# WARNING:pgmpy:Replacing existing CPD for Syncope, Vasovagal
# WARNING:pgmpy:Replacing existing CPD for Jaundice, Obstructive
# WARNING:pgmpy:Replacing existing CPD for Horner Syndrome
# WARNING:pgmpy:Replacing existing CPD for Toothache
# WARNING:pgmpy:Replacing existing CPD for Muscle Hypotonia
# WARNING:pgmpy:Replacing existing CPD for Catalepsy
# WARNING:pgmpy:Replacing existing CPD for Tetany
# WARNING:pgmpy:Replacing existing CPD for Consciousness Disorders
# WARNING:pgmpy:Replacing existing CPD for Dysarthria
# WARNING:pgmpy:Replacing existing CPD for Respiratory Paralysis
# WARNING:pgmpy:Replacing existing CPD for Aphasia, Broca
# WARNING:pgmpy:Replacing existing CPD for Scotoma
# WARNING:pgmpy:Replacing existing CPD for Muscle Cramp
# WARNING:pgmpy:Replacing existing CPD for Articulation Disorders
# WARNING:pgmpy:Replacing existing CPD for Vision, Low
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Bilateral
# WARNING:pgmpy:Replacing existing CPD for Muscle Rigidity
# WARNING:pgmpy:Replacing existing CPD for Hypesthesia
# WARNING:pgmpy:Replacing existing CPD for Hyperemesis Gravidarum
# WARNING:pgmpy:Replacing existing CPD for Taste Disorders
# WARNING:pgmpy:Replacing existing CPD for Persistent Vegetative State
# WARNING:pgmpy:Replacing existing CPD for Gastroparesis
# WARNING:pgmpy:Replacing existing CPD for Reflex, Abnormal
# WARNING:pgmpy:Replacing existing CPD for Decerebrate State
# WARNING:pgmpy:Replacing existing CPD for Auditory Perceptual Disorders
# WARNING:pgmpy:Replacing existing CPD for Phantom Limb
# WARNING:pgmpy:Replacing existing CPD for Hematemesis
# WARNING:pgmpy:Replacing existing CPD for Hypoventilation
# WARNING:pgmpy:Replacing existing CPD for Communication Disorders
# WARNING:pgmpy:Replacing existing CPD for Oral Hemorrhage
# WARNING:pgmpy:Replacing existing CPD for Myotonia
# WARNING:pgmpy:Replacing existing CPD for Dyskinesias
# WARNING:pgmpy:Replacing existing CPD for Polyuria
# WARNING:pgmpy:Replacing existing CPD for Fetal Macrosomia
# WARNING:pgmpy:Replacing existing CPD for Athetosis
# WARNING:pgmpy:Replacing existing CPD for Presbycusis
# WARNING:pgmpy:Replacing existing CPD for Tinea Pedis
# WARNING:pgmpy:Replacing existing CPD for Dyslexia, Acquired
# WARNING:pgmpy:Replacing existing CPD for Mutism
# WARNING:pgmpy:Replacing existing CPD for Hoarseness
# WARNING:pgmpy:Replacing existing CPD for Hypokinesia
# WARNING:pgmpy:Replacing existing CPD for Amnesia, Retrograde
# WARNING:pgmpy:Replacing existing CPD for Somatosensory Disorders
# WARNING:pgmpy:Replacing existing CPD for Postoperative Nausea and Vomiting
# WARNING:pgmpy:Replacing existing CPD for Anomia
# WARNING:pgmpy:Replacing existing CPD for Agraphia
# WARNING:pgmpy:Replacing existing CPD for Trismus
# WARNING:pgmpy:Replacing existing CPD for Cerebrospinal Fluid Otorrhea
# WARNING:pgmpy:Replacing existing CPD for Akathisia, Drug-Induced
# WARNING:pgmpy:Replacing existing CPD for Aphasia, Wernicke
# WARNING:pgmpy:Replacing existing CPD for Hemifacial Spasm
# WARNING:pgmpy:Replacing existing CPD for Muscle Hypertonia
# WARNING:pgmpy:Replacing existing CPD for Encopresis
# WARNING:pgmpy:Replacing existing CPD for Hyperesthesia
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, High-Frequency
# WARNING:pgmpy:Replacing existing CPD for Pupil Disorders
# WARNING:pgmpy:Replacing existing CPD for Eye Hemorrhage
# WARNING:pgmpy:Replacing existing CPD for Ecchymosis
# WARNING:pgmpy:Replacing existing CPD for Hemoglobinuria
# WARNING:pgmpy:Replacing existing CPD for Oliguria
# WARNING:pgmpy:Replacing existing CPD for Mouth Breathing
# WARNING:pgmpy:Replacing existing CPD for Ophthalmoplegia, Chronic Progressive External
# WARNING:pgmpy:Replacing existing CPD for Cheyne-Stokes Respiration
# WARNING:pgmpy:Replacing existing CPD for Fasciculation
# WARNING:pgmpy:Replacing existing CPD for Labor Pain
# WARNING:pgmpy:Replacing existing CPD for Blindness, Cortical
# WARNING:pgmpy:Replacing existing CPD for Neuralgia, Postherpetic
# WARNING:pgmpy:Replacing existing CPD for Prosopagnosia
# WARNING:pgmpy:Replacing existing CPD for Earache
# WARNING:pgmpy:Replacing existing CPD for Tics
# WARNING:pgmpy:Replacing existing CPD for Dysphonia
# WARNING:pgmpy:Replacing existing CPD for Amnesia, Transient Global
# WARNING:pgmpy:Replacing existing CPD for Respiratory Aspiration
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Central
# WARNING:pgmpy:Replacing existing CPD for Aphasia, Primary Progressive
# WARNING:pgmpy:Replacing existing CPD for Waterhouse-Friderichsen Syndrome
# WARNING:pgmpy:Replacing existing CPD for Edema, Cardiac
# WARNING:pgmpy:Replacing existing CPD for Paraparesis, Spastic
# WARNING:pgmpy:Replacing existing CPD for Paraparesis
# WARNING:pgmpy:Replacing existing CPD for Illusions
# WARNING:pgmpy:Replacing existing CPD for Urinary Incontinence, Urge
# WARNING:pgmpy:Replacing existing CPD for Glossalgia
# WARNING:pgmpy:Replacing existing CPD for Neurologic Manifestations
# WARNING:pgmpy:Replacing existing CPD for Purpura, Hyperglobulinemic
# WARNING:pgmpy:Replacing existing CPD for Brown-Sequard Syndrome
# WARNING:pgmpy:Replacing existing CPD for Dysgeusia
# WARNING:pgmpy:Replacing existing CPD for Usher Syndromes
# WARNING:pgmpy:Replacing existing CPD for Korsakoff Syndrome
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Unilateral
# WARNING:pgmpy:Replacing existing CPD for Gait Ataxia
# WARNING:pgmpy:Replacing existing CPD for Sarcopenia
# WARNING:pgmpy:Replacing existing CPD for Hyperacusis
# WARNING:pgmpy:Replacing existing CPD for Amnesia, Anterograde
# WARNING:pgmpy:Replacing existing CPD for Dyspnea, Paroxysmal
# WARNING:pgmpy:Replacing existing CPD for Ageusia
# WARNING:pgmpy:Replacing existing CPD for Photophobia
# WARNING:pgmpy:Replacing existing CPD for Aphonia
# WARNING:pgmpy:Replacing existing CPD for Cafe-au-Lait Spots
# WARNING:pgmpy:Replacing existing CPD for Amaurosis Fugax
# WARNING:pgmpy:Replacing existing CPD for Miosis
# WARNING:pgmpy:Replacing existing CPD for Anisocoria
# WARNING:pgmpy:Replacing existing CPD for Apraxia, Ideomotor
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Functional
# WARNING:pgmpy:Replacing existing CPD for Gerstmann Syndrome
# WARNING:pgmpy:Replacing existing CPD for Meningism
# WARNING:pgmpy:Replacing existing CPD for Cardiac Output, High
# WARNING:pgmpy:Replacing existing CPD for Tonic Pupil
# WARNING:pgmpy:Replacing existing CPD for Pain, Referred
# WARNING:pgmpy:Replacing existing CPD for Echolalia
# WARNING:pgmpy:Replacing existing CPD for Myokymia
# WARNING:pgmpy:Replacing existing CPD for Pseudobulbar Palsy
# WARNING:pgmpy:Replacing existing CPD for Livedo Reticularis
# WARNING:pgmpy:Replacing existing CPD for Coprophagia
# WARNING:pgmpy:Replacing existing CPD for Orthostatic Intolerance
# WARNING:pgmpy:Replacing existing CPD for Purpura Fulminans
# WARNING:pgmpy:Replacing existing CPD for Synkinesis
# WARNING:pgmpy:Replacing existing CPD for Metatarsalgia
# WARNING:pgmpy:Replacing existing CPD for Eye Manifestations
# WARNING:pgmpy:Replacing existing CPD for Hearing Loss, Mixed Conductive-Sensorineural
# WARNING:pgmpy:Replacing existing CPD for Alexia, Pure
# WARNING:pgmpy:Replacing existing CPD for Aphasia, Conduction
# WARNING:pgmpy:Replacing existing CPD for Oral Manifestations
# WARNING:pgmpy:Replacing existing CPD for Gait Apraxia
# WARNING:pgmpy:Replacing existing CPD for Morning Sickness
# WARNING:pgmpy:Replacing existing CPD for Reflex, Babinski
# WARNING:pgmpy:Replacing existing CPD for Lethargy
# WARNING:pgmpy:Replacing existing CPD for Susac Syndrome
# WARNING:pgmpy:Replacing existing CPD for Stupor
# WARNING:pgmpy:Replacing existing CPD for Eye Pain
# WARNING:pgmpy:Replacing existing CPD for Deaf-Blind Disorders
# WARNING:pgmpy:Replacing existing CPD for Primary Progressive Nonfluent Aphasia
# WARNING:pgmpy:Replacing existing CPD for Piriformis Muscle Syndrome
# WARNING:pgmpy:Replacing existing CPD for Alien Hand Syndrome
# WARNING:pgmpy:Replacing existing CPD for Necrolytic Migratory Erythema
# WARNING:pgmpy:Replacing existing CPD for Infantile Apparent Life-Threatening Event
# WARNING:pgmpy:Replacing existing CPD for Slit Ventricle Syndrome
# 4442
# [0.004925566634835935, 0.0048398910299983664, 0.001789429660035687, 0.0016434493583990099, 0.0014357006537302358, 0.0009346252199706517, 0.0009040825499089673, 0.0009005696549497958, 0.0008508036430282013, 0.0006786717900288038, 0.0006688161680600174, 0.0006585702244291009, 0.0006523250778350184, 0.0006262711068878307, 0.0005990461709542526, 0.0005946550522552883, 0.0005926058635291051, 0.0005732849412536624, 0.0005483043548773326, 0.0005127850836234888, 0.00045072393934479437, 0.00044516185565943964, 0.0004378433244944993, 0.0004373554224168366, 0.00043696510075470643, 0.0004331594645489375, 0.00043208607997807953, 0.00042984173042083117, 0.00042789012211018036, 0.0004120820947939092, 0.00039900631911254903, 0.0003884676342350349, 0.00037500153689154465, 0.0003708055790236455, 0.0003687563902974622, 0.00036709752323340906, 0.0003657313974159535, 0.0003598765724840012, 0.0003394822656377007, 0.0003303097065776421, 0.0003285532590980564, 0.0003284556786825239, 0.00032513794455441757, 0.00032250327333503904, 0.0003208444062709859, 0.00031811215463607484, 0.00031342829469051297, 0.0003065976656032353, 0.0002964493023878513, 0.00029518075698592834, 0.0002929364074286799, 0.00029254608576654976, 0.00029186302285782203, 0.0002912775403646268, 0.0002901065753782363, 0.00028649610000353244, 0.00027381064598430244, 0.0002730300026600421, 0.0002622961569514629, 0.0002610276115495399, 0.0002584905207456939, 0.00025810019908356375, 0.00025302601747587177, 0.00025136715041181864, 0.0002509768287496885, 0.00024717119254391947, 0.00024434136049347586, 0.0002375107314061982, 0.00023692524891300297, 0.00022414221447824043, 0.00021858013079288576, 0.00021770190705309292, 0.00020862692840856685, 0.0002056995159425907, 0.00020530919428046054, 0.00020501645303386295, 0.0001985761456087154, 0.0001957463135582718, 0.0001949656702340115, 0.00019155035569037266, 0.00018784229990013621, 0.00018676891532927827, 0.00017505926546537367, 0.0001710584684285396, 0.00016978992302661662, 0.00016705767139170555, 0.00015681172776078902, 0.00015642140609865886, 0.00015554318235886603, 0.00015515286069673587, 0.0001491028749337185, 0.00014724884703860028, 0.00014393111291049397, 0.0001424674066775059, 0.0001307577568136013, 0.0001294892114116783, 0.0001253908339593117, 0.00011973116985842448, 0.0001187553657030991, 0.00011651101614585071, 0.0001154376315749928, 0.00011475456866626503, 0.00011358360367987456, 0.0001075336179168572, 0.00010567959002173896, 0.00010431346420428343, 0.00010275217755576281, 0.0001024594363091652, 0.00010089814966064459, 0.00010080056924511205, 9.728767428594067e-05, 9.20183318471836e-05, 9.055462561419553e-05, 8.909091938120745e-05, 8.694415023949161e-05, 8.61635069152313e-05, 8.606592649969878e-05, 8.313851403372263e-05, 8.011352115221394e-05, 7.952803865901871e-05, 7.904013658135601e-05, 7.87473953347584e-05, 7.82594932570957e-05, 7.82594932570957e-05, 7.718610868623779e-05, 7.523450037558703e-05, 7.386837455813148e-05, 7.338047248046879e-05, 7.055064043002518e-05, 6.937967544363473e-05, 6.811113004171172e-05, 6.654984339319112e-05, 6.537887840680065e-05, 6.528129799126811e-05, 6.518371757573557e-05, 6.362243092721497e-05, 6.332968968061735e-05, 6.206114427869435e-05, 6.196356386316181e-05, 6.196356386316181e-05, 6.04022772146412e-05, 6.0011955552511044e-05, 5.903615139718566e-05, 5.864582973505551e-05, 5.8450668903990436e-05, 5.669422142440475e-05, 5.552325643801429e-05, 5.298616563416829e-05, 5.0546655245854835e-05, 4.966843150606199e-05, 4.8497466519671526e-05, 4.781440361094376e-05, 4.66434386245533e-05, 4.6350697377955684e-05, 4.322812408091446e-05, 4.313054366538192e-05, 4.215473951005654e-05, 4.2057159094524e-05, 4.147167660132877e-05, 4.010555078387324e-05, 4.00079703683407e-05, 3.981280953727562e-05, 3.6690236240234395e-05, 3.62023341625717e-05, 3.590959291597409e-05, 3.5616851669376474e-05, 3.522653000724632e-05, 3.454346709851855e-05, 3.454346709851855e-05, 3.366524335872571e-05, 3.190879587914002e-05, 3.122573297041225e-05 ...

# %%
# Step 5: Calculate conditional probability tables

total_prob = sum(prior_prob_list)
idiopathic_disease_CPD = 1 - total_prob

# create dictionary to index co-occurrences
co_occur_dict = {} # dictionary = symptom : [[Diseases, Occurrence]]
total_co_occurrences = 0

# Fill the dictionary
for i in range(len(cooccurrences)):
    disease = cooccurrences[i][1]
    symptom = cooccurrences[i][0]
    occurrence = cooccurrences[i][2]
    total_co_occurrences += occurrence
    if occurrence > 500:
        if not symptom in co_occur_dict.keys():
            co_occur_dict[symptom] = []
        co_occur_dict.get(symptom).append([disease, occurrence])

# print(co_occur_dict)

# Calculate CPTs
CPTs = {}
for symptom, disease_list in co_occur_dict.items():
    total_occurrences_for_symptom = sum([item[1] for item in disease_list])
    CPT = {}
    for disease, occurrence in disease_list:
        CPT[disease] = occurrence / total_occurrences_for_symptom

    # assign remaining probabilities to idiopathic diseases
    CPT["idiopathic disease"] = idiopathic_disease_CPD * (total_occurrences_for_symptom / total_co_occurrences)
    CPTs[symptom] = CPT

# Print CPTs
for symptom, CPT in CPTs.items():
    print(f"Symptom: {symptom}")
    for disease, prob in CPT.items():
        cpd = TabularCPD(variable = disease, 
                         variable_card = 2,
                         values = [[1 - prob], [prob]])
        model.add_cpds(cpd)
        print(f"Disease: {disease}, Probability: {prob:.4f}")




# assert model.check_model()
# Out:
# Symptom: Fever
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 42
#      38 for disease, prob in CPT.items():
#      39     cpd = TabularCPD(variable = disease,
#      40                      variable_card = 2,
#      41                      values = [[1 - prob], [prob]])
# ---> 42     model.add_cpds(cpd)
#      43     print(f"Disease: {disease}, Probability: {prob:.4f}")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pgmpy/models/BayesianNetwork.py:259, in BayesianNetwork.add_cpds(self, *cpds)
#     256     raise ValueError("Only TabularCPD or ContinuousFactor can be added.")
#     258 if set(cpd.scope()) - set(cpd.scope()).intersection(set(self.nodes())):
# --> 259     raise ValueError("CPD defined on variable not in the model", cpd)
#     261 for prev_cpd_index in range(len(self.cpds)):
#     262     if self.cpds[prev_cpd_index].variable == cpd.variable:
#
# ValueError: ('CPD defined on variable not in the model', <TabularCPD representing P(Bacterial Infections:2) at 0x1f63c7290>)

# %%
# Step 6: Create a minimal interface

def most_likely_disease_fxn(symptoms, CPTs):

    disease_probabilities = {}

    for symptom in symptoms:
        if symptom in CPTs:
            for disease, prob in CPTs[symptom].items():
                if disease not in disease_probabilities:
                    disease_probabilities[disease] = 1
                disease_probabilities[disease] *= prob

        else:
            print(f"Symptom '{symptom}' is not recognized")

    total_prob = sum(disease_probabilities.values())
    for disease in disease_probabilities:
        disease_probabilities[disease] /= total_prob

    most_likely_disease = max(disease_probabilities, key = disease_probabilities.get)

    return most_likely_disease


def main():

    user_input = input("Please enter your observed symptoms separated by commas: ")
    symptoms = [symptom.strip() for symptom in user_input.split(",")]

    most_likely_disease = most_likely_disease_fxn(symptoms, CPTs)

    print(f"Based on your symptoms, the most likely disease is: {most_likely_disease}")

if __name__ == "__main__":
    main()
# Out:
# Based on your symptoms, the most likely disease is: Obesity
